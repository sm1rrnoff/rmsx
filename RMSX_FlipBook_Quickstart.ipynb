# %% [markdown]
# # RMSX Demonstration
#
# This notebook includes everything you need to run **RMSX** and **Flipbook**. Just run each cell. You are encouraged to try different parameters and use your own trajectories directly within this notebook or by making a copy of it.
#
#
# We'll cover:
#
# 1. Environment setup
# 2. Loading demo input files
# 3. Single-chain RMSX
# 4. Multi-chain RMSX
# 5. FlipBook snapshots (optional)
# 6. Interpreting results
#
# > **Note:** Adjust file paths as needed for your machine. We reccomend not editing the first two cells, though.

# %% [markdown]
# ## 1) Environment Setup
#
# - **R** — used for heatmaps and RMSD/RMSF plots via `Rscript`.
# - **ChimeraX** (optional) — used for FlipBook image generation.

# %% [markdown]
# ### Quick Start

# %%
# One-click install for this kernel (no sudo; no Plotly required)
import sys, os, site, tempfile, urllib.request, subprocess, shutil

def _ensure_pip_in_kernel():
    try:
        import pip  # noqa: F401
        return
    except Exception:
        pass
    # Bootstrap pip into THIS kernel if it's missing
    print("Bootstrapping pip into this Jupyter kernel…")
    with tempfile.TemporaryDirectory() as td:
        gp = os.path.join(td, "get-pip.py")
        urllib.request.urlretrieve("https://bootstrap.pypa.io/get-pip.py", gp)
        subprocess.check_call([sys.executable, gp, "--user"])
    # Make sure user-site is importable in this process
    us = site.getusersitepackages()
    if us not in sys.path:
        sys.path.append(us)

_ensure_pip_in_kernel()

# Use Jupyter's %pip so installs target THIS kernel

# %pip install -U pip wheel setuptools
# %pip install -U "numpy>=1.26,<2.0" "pandas>=2.2,<2.3" "MDAnalysis>=2.6,<3" "scipy>=1.10" "plotly>=5"
# %pip install -U "git+https://github.com/AntunesLab/rmsx.git@main" plotly>=5

# Optional: show Rscript (for plots) if available
import subprocess
RSCRIPT = os.environ.get("RSCRIPT", "Rscript")
try:
    out = subprocess.run([RSCRIPT, "-e", "cat(R.version.string)"] , capture_output=True, text=True)
    print(out.stdout or out.stderr or "Rscript OK")
except FileNotFoundError:
    print("⚠️ Rscript not found. Heatmap/RMSD/RMSF plots will be skipped until R is installed or RSCRIPT is set.")
# Out:
# Requirement already satisfied: pip in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (25.3)
# Requirement already satisfied: wheel in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (0.45.1)
# Requirement already satisfied: setuptools in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (80.9.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy<2.0,>=1.26 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas<2.3,>=2.2 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: MDAnalysis<3,>=2.6 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (2.9.0)
# Requirement already satisfied: scipy>=1.10 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (1.15.3)
# Requirement already satisfied: plotly>=5 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (6.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from pandas<2.3,>=2.2) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from pandas<2.3,>=2.2) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from pandas<2.3,>=2.2) (2025.2)
# Requirement already satisfied: GridDataFormats>=0.4.0 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (1.0.2)
# Requirement already satisfied: mmtf-python>=1.0.0 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (1.1.3)
# Requirement already satisfied: joblib>=0.12 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (1.5.2)
# Requirement already satisfied: matplotlib>=1.5.1 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (3.10.7)
# Requirement already satisfied: tqdm>=4.43.0 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (4.67.1)
# Requirement already satisfied: threadpoolctl in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (3.6.0)
# Requirement already satisfied: packaging in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (24.1)
# Requirement already satisfied: filelock in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (3.20.0)
# Requirement already satisfied: mda-xdrlib in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from MDAnalysis<3,>=2.6) (0.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from plotly>=5) (2.11.0)
# Requirement already satisfied: mrcfile in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from GridDataFormats>=0.4.0->MDAnalysis<3,>=2.6) (1.5.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from matplotlib>=1.5.1->MDAnalysis<3,>=2.6) (3.2.5)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from mmtf-python>=1.0.0->MDAnalysis<3,>=2.6) (1.1.2)
# Requirement already satisfied: six>=1.5 in /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: 5 not found
# Note: you may need to restart the kernel to use updated packages.
# R version 4.5.1 (2025-06-13)

# %%
# Imports & locate sample data
from pathlib import Path
import os, subprocess

from rmsx import run_rmsx, run_rmsx_flipbook, all_chain_rmsx, run_shift_flipbook
import rmsx

pkg_dir = Path(rmsx.__file__).resolve().parent

# Optional: set this to use your own dataset folder
# os.environ["RMSX_TEST_DIR"] = "/path/to/test_files"
env_override = os.environ.get("RMSX_TEST_DIR")

candidates = []
if env_override:
    candidates.append(Path(env_override))

candidates += [
    Path.cwd() / "test_files",              # next to this notebook
    Path.cwd() / "rmsx" / "test_files",     # if you cloned into ./rmsx
    pkg_dir / "test_files",                 # packaged tests (if included)
    pkg_dir.parent / "test_files",          # repo layout when running from source
]

test_dir = next((p for p in candidates if p.exists()), None)

# Last resort: clone repo to fetch sample data (does not affect installed package)
if not test_dir:
    REPO_URL = "https://github.com/AntunesLab/rmsx.git"
    REPO_DIR = Path.cwd() / "rmsx"
    if not REPO_DIR.exists():
        print("Cloning RMSX repo to retrieve sample data…")
        subprocess.check_call(["git", "clone", REPO_URL, str(REPO_DIR)])
    test_dir = REPO_DIR / "test_files"
    if not test_dir.exists():
        raise FileNotFoundError("Couldn't locate test_files after cloning. Please report this issue.")

# Single-chain demo (Ubiquitin)
pdb_file   = (test_dir / "1UBQ.pdb").as_posix()
dcd_file   = (test_dir / "mon_sys.dcd").as_posix()
output_dir = (test_dir / "example_uqb").as_posix()

# Multi-chain demo (protease) — files live directly under test_files/
pdb_file_multi   = (test_dir / "protease_backbone.pdb").as_posix()
traj_file_multi  = (test_dir / "short_protease_backbone.dcd").as_posix()
output_dir_multi = (test_dir / "protease").as_posix()

print("Single-chain inputs:")
print("  PDB:", pdb_file)
print("  DCD:", dcd_file)
print("  out:", output_dir)

print("\nMulti-chain inputs:")
print("  PDB:", pdb_file_multi)
print("  DCD:", traj_file_multi)
print("  out:", output_dir_multi)
# Out:
# Single-chain inputs:
#   PDB: /Users/finn/Documents/GitHub/rmsx/test_files/1UBQ.pdb
#   DCD: /Users/finn/Documents/GitHub/rmsx/test_files/mon_sys.dcd
#   out: /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb
#
# Multi-chain inputs:
#   PDB: /Users/finn/Documents/GitHub/rmsx/test_files/protease_backbone.pdb
#   DCD: /Users/finn/Documents/GitHub/rmsx/test_files/short_protease_backbone.dcd
#   out: /Users/finn/Documents/GitHub/rmsx/test_files/protease

# %% [markdown]
# *Windows users: if R isn’t on PATH, set `RSCRIPT` before running:*

# %%
import os
# os.environ["RSCRIPT"] = r"C:\\Program Files\\R\\R-4.4.1\\bin\\Rscript.exe"  # <- edit if needed
# !pwd
# Out:
# /Users/finn/Documents/GitHub/rmsx

# %% [markdown]
# ## 2) Load Demo Input Files
#
# These come with the package as `test_files`. Rather than editing these we recocomend adding your paths in later cells.

# %% [markdown]
# ## 3) Single-Chain RMSX
#
# `run_rmsx` computes per-slice RMSX and generates:
# - RMSX heatmap
# - RMSD time series
# - RMSF per-residue
#
# Edit `palette` and `chain_sele` as needed. (For the included Ubiquitin demo, the chain is `"7"`.)

# %%
from rmsx import *


run_rmsx(
    topology_file=pdb_file,        # PDB or topology file
    trajectory_file=dcd_file,      # Trajectory file
    output_dir=output_dir,         # Where to save results
    num_slices=9,                  # Select number of slices and it will autogenerate slice size 
    slice_size=None,               # OR: select slice size and it will choose number of slices 
    rscript_executable=os.environ.get('RSCRIPT', 'Rscript'),
    verbose=True,                 
    interpolate=False,             # Interpolate between heatmap cells (use with caution)
    triple=True,                   # Generate RMSX, RMSD, and RMSF plots
    overwrite=True,                # Automatically overwrite old directory
    palette="mako",                # Try other colors: viridis, turbo, magma or plasma etc.
    chain_sele="7",                # Set to your chain ID or None to be prompted with available chain 
    start_frame=0,                 # Default to the first frame of the simulation
    end_frame=None,                # Default to None (last frame of simulation)
    full_backbone=True
)
# Out:
# Python Executable: /Users/finn/miniconda3/envs/testing_ngl/bin/python
# Current Working Directory: /Users/finn/Documents/GitHub/rmsx
# Overwriting existing directory: /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx
# The directory '/Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx' is ready for use.
# Starting analysis...
# Using the slicing method with num_slices=9
# Truncating 1 excess frame(s). Original size: 316, Updated: 315
# Processing frames 0 to 314 of the trajectory.
# Number of slices: 9
# First frame of slice 1 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_1_first_frame.pdb
# Slice 1: RMSF computed for frames 0 to 34 (35 frames)
# First frame of slice 2 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_2_first_frame.pdb
# Slice 2: RMSF computed for frames 35 to 69 (35 frames)
# First frame of slice 3 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_3_first_frame.pdb
# Slice 3: RMSF computed for frames 70 to 104 (35 frames)
# First frame of slice 4 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_4_first_frame.pdb
# Slice 4: RMSF computed for frames 105 to 139 (35 frames)
# First frame of slice 5 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_5_first_frame.pdb
# Slice 5: RMSF computed for frames 140 to 174 (35 frames)
# First frame of slice 6 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_6_first_frame.pdb
# Slice 6: RMSF computed for frames 175 to 209 (35 frames)
# First frame of slice 7 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_7_first_frame.pdb
# Slice 7: RMSF computed for frames 210 to 244 (35 frames)
# First frame of slice 8 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_8_first_frame.pdb
# Slice 8: RMSF computed for frames 245 to 279 (35 frames)
# First frame of slice 9 written to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_9_first_frame.pdb
# Slice 9: RMSF computed for frames 280 to 314 (35 frames)
# RMSX data saved to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsx_mon_sys_0.015_ns.csv
# RMSD data saved to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsd.csv
# Number of residues: 76
# RMSF data saved to /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsf.csv
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_1_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_2_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_3_first_frame.pdb
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_4_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_5_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_6_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_7_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_8_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/slice_9_first_frame.pdb
# Generating plots...
# Found R script at /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R.
# Running R script command:
# Rscript /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsx_mon_sys_0.015_ns.csv /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsd.csv /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsf.csv FALSE TRUE mako   FALSE
# R script executed successfully.
# R STDOUT:
#  # A tibble: 1 × 2
#   ChainID Count
#     <dbl> <int>
# 1       7    76
#
# Displaying image: /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx/rmsx_mon_sys_0.015_ns_rmsx_plot_chain_7.png
# Now summarizing the top 3 and bottom 3 RMSX values...
#
# ===== Top 3 RMSX values across all slices =====
# TimeSlice: slice_2.dcd, ChainID: 7, ResidueID: 76, RMSX: 9.616
# TimeSlice: slice_1.dcd, ChainID: 7, ResidueID: 75, RMSX: 7.957
# TimeSlice: slice_2.dcd, ChainID: 7, ResidueID: 75, RMSX: 7.496
#
# ===== Bottom 3 RMSX values across all slices =====
# TimeSlice: slice_1.dcd, ChainID: 7, ResidueID: 48, RMSX: 0.000
# TimeSlice: slice_2.dcd, ChainID: 7, ResidueID: 48, RMSX: 0.000
# TimeSlice: slice_3.dcd, ChainID: 7, ResidueID: 48, RMSX: 0.000
# (     ResidueID  ChainID    TimeSlice      RMSX
#  151         76        7  slice_2.dcd  9.616028
#  74          75        7  slice_1.dcd  7.957497
#  150         75        7  slice_2.dcd  7.495831,
#       ResidueID  ChainID    TimeSlice  RMSX
#  47          48        7  slice_1.dcd   0.0
#  123         48        7  slice_2.dcd   0.0
#  199         48        7  slice_3.dcd   0.0)

# %%
run_shift_flipbook(
    topology_file=pdb_file,
    trajectory_file=dcd_file,
    output_dir=output_dir,
    num_slices=16,
    slice_size=None,
    rscript_executable=os.environ.get('RSCRIPT', 'Rscript'),
    verbose=False,
    interpolate=False,
    triple=True,
    overwrite=True,
    palette="turbo",
    start_frame=0,
    end_frame=150,
    sync_color_scale=True,           # Useful when chains have very different RMSX values, True will force the same color key/scale to be used
    full_backbone=True,
    viewer="vmd"
)
# Out:
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Detected B-factor range: 0.00 - 67.98
# [flipbook] Using VMD backend (PTY Mode)...
# [flipbook] Launching VMD in PTY:
#   /Applications/VMD 2.0.0a7-pre2.app/Contents/vmd2/lib/vmd_MACOSXARM64 -dispdev win -e /Users/finn/Documents/GitHub/rmsx/rmsx/vmd_scripts/wait_to_load.tcl -args /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_1_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_2_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_3_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_4_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_5_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_6_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_7_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_8_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_9_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_10_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_11_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_12_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_13_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_14_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_15_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_shiftmap/slice_16_first_frame.pdb turbo

# %%
# !Rscript -e 'user<-Sys.getenv("R_LIBS_USER"); if(user=="") user<-file.path(Sys.getenv("HOME"),"R","library"); dir.create(user,recursive=TRUE,showWarnings=FALSE); .libPaths(c(user,.libPaths())); install.packages(c("ggplot2","viridis","dplyr","tidyr","stringr","readr","gridExtra"), lib=user, dependencies=c("Depends","Imports","LinkingTo"))'
# Out:
# Error in contrib.url(repos, "source") :
#   trying to use CRAN without setting a mirror
# Calls: install.packages -> contrib.url
# Execution halted

# %% [markdown]
# ## 4) Multi-Chain RMSX
#
# `all_chain_rmsx` runs RMSX for **every** chain in the topology. If you set `sync_color_scale=True`,
# all plots share a consistent colorbar range.

# %%
all_chain_rmsx(
    topology_file=pdb_file,
    trajectory_file=dcd_file,
    output_dir=output_dir,
    num_slices=12,
    slice_size=None,
    rscript_executable=os.environ.get('RSCRIPT', 'Rscript'),
    verbose=False,
    interpolate=False,
    triple=True,
    overwrite=True,
    palette="turbo",
    start_frame=0,
    end_frame=None,
    sync_color_scale=True           # Useful when chains have very different RMSX values, True will force the same color key/scale to be used
)
# Out:
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# '/Users/finn/Documents/GitHub/rmsx/test_files/example_uqb/chain_7_rmsx'

# %% [markdown]
# ## 5) FlipBook (optional)
#
# FlipBook maps RMSX values (stored in the PDB B-factor column) onto 3D structures and lays out snapshots side-by-side.

# %%
run_rmsx_flipbook(
    topology_file=pdb_file_multi,
    trajectory_file=traj_file_multi,
    output_dir=output_dir_multi,
    num_slices=9,
    slice_size=None,
    rscript_executable=os.environ.get('RSCRIPT', 'Rscript'),
    verbose=True,
    interpolate=False,
    triple=True,
    overwrite=True,
    palette="magma",         # automatically matches color palette for heatmap and chimeraX structures
    spacingFactor="0.9",     # how much space between the snapshots; 1 is default
    start_frame=0,
    end_frame=None,
    viewer="vmd"
)
# Out:
# Clearing main output directory: /Users/finn/Documents/GitHub/rmsx/test_files/protease
#
# Analyzing Chain A...
# Python Executable: /Users/finn/miniconda3/envs/testing_ngl/bin/python
# Current Working Directory: /Users/finn/Documents/GitHub/rmsx
# The directory '/Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx' is ready for use.
# Starting analysis...
# Using the slicing method with num_slices=9
# Truncating 6 excess frame(s). Original size: 5001, Updated: 4995
# Processing frames 0 to 4994 of the trajectory.
# Number of slices: 9
# First frame of slice 1 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_1_first_frame.pdb
# Slice 1: RMSF computed for frames 0 to 554 (555 frames)
# First frame of slice 2 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_2_first_frame.pdb
# Slice 2: RMSF computed for frames 555 to 1109 (555 frames)
# First frame of slice 3 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_3_first_frame.pdb
# Slice 3: RMSF computed for frames 1110 to 1664 (555 frames)
# First frame of slice 4 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_4_first_frame.pdb
# Slice 4: RMSF computed for frames 1665 to 2219 (555 frames)
# First frame of slice 5 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_5_first_frame.pdb
# Slice 5: RMSF computed for frames 2220 to 2774 (555 frames)
# First frame of slice 6 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_6_first_frame.pdb
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Slice 6: RMSF computed for frames 2775 to 3329 (555 frames)
# First frame of slice 7 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_7_first_frame.pdb
# Slice 7: RMSF computed for frames 3330 to 3884 (555 frames)
# First frame of slice 8 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_8_first_frame.pdb
# Slice 8: RMSF computed for frames 3885 to 4439 (555 frames)
# First frame of slice 9 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_9_first_frame.pdb
# Slice 9: RMSF computed for frames 4440 to 4994 (555 frames)
# RMSX data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsx_short_protease_backbone_4.995_ns.csv
# RMSD data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsd.csv
# Number of residues: 99
# RMSF data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsf.csv
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_1_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_2_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_3_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_4_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_5_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_6_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_7_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_8_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/slice_9_first_frame.pdb
# Skipping plot generation in run_rmsx() because make_plot=False.
#
# Now summarizing the top 3 and bottom 3 RMSX values...
#
# ===== Top 3 RMSX values across all slices =====
# TimeSlice: slice_6.dcd, ChainID: A, ResidueID: 51, RMSX: 3.412
# TimeSlice: slice_8.dcd, ChainID: A, ResidueID: 51, RMSX: 3.366
# TimeSlice: slice_8.dcd, ChainID: A, ResidueID: 50, RMSX: 3.111
#
# ===== Bottom 3 RMSX values across all slices =====
# TimeSlice: slice_4.dcd, ChainID: A, ResidueID: 31, RMSX: 0.341
# TimeSlice: slice_3.dcd, ChainID: A, ResidueID: 31, RMSX: 0.349
# TimeSlice: slice_3.dcd, ChainID: A, ResidueID: 76, RMSX: 0.351
#
#
# Analyzing Chain B...
# Python Executable: /Users/finn/miniconda3/envs/testing_ngl/bin/python
# Current Working Directory: /Users/finn/Documents/GitHub/rmsx
# The directory '/Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx' is ready for use.
# Starting analysis...
# Using the slicing method with num_slices=9
# Truncating 6 excess frame(s). Original size: 5001, Updated: 4995
# Processing frames 0 to 4994 of the trajectory.
# Number of slices: 9
# First frame of slice 1 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_1_first_frame.pdb
# Slice 1: RMSF computed for frames 0 to 554 (555 frames)
# First frame of slice 2 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_2_first_frame.pdb
# Slice 2: RMSF computed for frames 555 to 1109 (555 frames)
# First frame of slice 3 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_3_first_frame.pdb
# Slice 3: RMSF computed for frames 1110 to 1664 (555 frames)
# First frame of slice 4 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_4_first_frame.pdb
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Slice 4: RMSF computed for frames 1665 to 2219 (555 frames)
# First frame of slice 5 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_5_first_frame.pdb
# Slice 5: RMSF computed for frames 2220 to 2774 (555 frames)
# First frame of slice 6 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_6_first_frame.pdb
# Slice 6: RMSF computed for frames 2775 to 3329 (555 frames)
# First frame of slice 7 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_7_first_frame.pdb
# Slice 7: RMSF computed for frames 3330 to 3884 (555 frames)
# First frame of slice 8 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_8_first_frame.pdb
# Slice 8: RMSF computed for frames 3885 to 4439 (555 frames)
# First frame of slice 9 written to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_9_first_frame.pdb
# Slice 9: RMSF computed for frames 4440 to 4994 (555 frames)
# RMSX data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsx_short_protease_backbone_4.995_ns.csv
# RMSD data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsd.csv
# Number of residues: 99
# RMSF data saved to /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsf.csv
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_1_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_2_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_3_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_4_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_5_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_6_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_7_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_8_first_frame.pdb
# Updated PDB B-factors in /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/slice_9_first_frame.pdb
# Skipping plot generation in run_rmsx() because make_plot=False.
#
# Now summarizing the top 3 and bottom 3 RMSX values...
#
# ===== Top 3 RMSX values across all slices =====
# TimeSlice: slice_9.dcd, ChainID: B, ResidueID: 49, RMSX: 3.274
# TimeSlice: slice_9.dcd, ChainID: B, ResidueID: 50, RMSX: 3.254
# TimeSlice: slice_6.dcd, ChainID: B, ResidueID: 50, RMSX: 2.959
#
# ===== Bottom 3 RMSX values across all slices =====
# TimeSlice: slice_4.dcd, ChainID: B, ResidueID: 85, RMSX: 0.350
# TimeSlice: slice_4.dcd, ChainID: B, ResidueID: 31, RMSX: 0.354
# TimeSlice: slice_4.dcd, ChainID: B, ResidueID: 76, RMSX: 0.362
#
#
# Combining PDB files from all chains...
# Correctly combined slice_2_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_2_first_frame.pdb
# Correctly combined slice_5_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_5_first_frame.pdb
# Correctly combined slice_4_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_4_first_frame.pdb
# Correctly combined slice_3_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_3_first_frame.pdb
# Correctly combined slice_9_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_9_first_frame.pdb
# Correctly combined slice_6_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_6_first_frame.pdb
# Correctly combined slice_1_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_1_first_frame.pdb
# Correctly combined slice_8_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_8_first_frame.pdb
# Correctly combined slice_7_first_frame.pdb from all chains into /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_7_first_frame.pdb
# Combined RMSX analysis completed for all chains.
#
# Computing global RMSX min and max across all chains...
# Global RMSX range = [0.341, 3.412]
# Generating final plots with a fixed color scale...
# Found R script at /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R.
# Running R script command:
# Rscript /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsx_short_protease_backbone_4.995_ns.csv /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsd.csv /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsf.csv FALSE TRUE magma 0.3414969829634701 3.4120392235972408 FALSE
# R script executed successfully.
# R STDOUT:
#  # A tibble: 1 × 2
#   ChainID Count
#   <chr>   <int>
# 1 A          99
#
# Displaying image: /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_A_rmsx/rmsx_short_protease_backbone_4.995_ns_rmsx_plot_chain_A.png
# Found R script at /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R.
# Running R script command:
# Rscript /Users/finn/Documents/GitHub/rmsx/rmsx/r_scripts/plot_rmsx.R /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsx_short_protease_backbone_4.995_ns.csv /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsd.csv /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsf.csv FALSE TRUE magma 0.3414969829634701 3.4120392235972408 FALSE
# R script executed successfully.
# R STDOUT:
#  # A tibble: 1 × 2
#   ChainID Count
#   <chr>   <int>
# 1 B          99
#
# Displaying image: /Users/finn/Documents/GitHub/rmsx/test_files/protease/chain_B_rmsx/rmsx_short_protease_backbone_4.995_ns_rmsx_plot_chain_B.png
# Detected B-factor range: 0.34 - 3.41
# [flipbook] Using VMD backend (PTY Mode)...
# [flipbook] Launching VMD in PTY:
#   /Applications/VMD 2.0.0a7-pre2.app/Contents/vmd2/lib/vmd_MACOSXARM64 -dispdev win -e /Users/finn/Documents/GitHub/rmsx/rmsx/vmd_scripts/wait_to_load.tcl -args /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_1_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_2_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_3_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_4_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_5_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_6_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_7_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_8_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_9_first_frame.pdb magma
# Full RMSX flipbook analysis completed successfully.

# %% [markdown]
# ### 5.1 Display the latest FlipBook image (if generated)
# If you don't like the orientation, try adjusting it in ChimeraX and rerunning the save command (see the ChimeraX log for details)

# %%
_which_chimerax(None)
# Out:
# [flipbook] macOS bundle candidates (sorted):
#    - ChimeraX-1.10.1.app -> /Applications/ChimeraX-1.10.1.app/Contents/MacOS/ChimeraX  (ver=1.10.1, daily=False)
#    - ChimeraX-1.8.app -> /Applications/ChimeraX-1.8.app/Contents/MacOS/ChimeraX  (ver=1.8, daily=False)
#    - ChimeraX-1.5.app -> /Applications/ChimeraX-1.5.app/Contents/MacOS/ChimeraX  (ver=1.5, daily=False)
#    - ChimeraX_Daily.app -> /Applications/ChimeraX_Daily.app/Contents/MacOS/ChimeraX  (ver=0, daily=True)
# [flipbook] Checking ChimeraX candidates (in order):
#    - macOS app bundle (ChimeraX-1.10.1.app): /Applications/ChimeraX-1.10.1.app/Contents/MacOS/ChimeraX
# [flipbook] Using ChimeraX installation: /Applications/ChimeraX-1.10.1.app/Contents/MacOS/ChimeraX
# '/Applications/ChimeraX-1.10.1.app/Contents/MacOS/ChimeraX'

# %%
run_rmsx_flipbook(
    topology_file=pdb_file_multi,
    trajectory_file=traj_file_multi,
    output_dir=output_dir_multi,
    num_slices=9,
    slice_size=None,
    rscript_executable=os.environ.get('RSCRIPT', 'Rscript'),
    verbose=False,
    interpolate=False,
    triple=True,
    overwrite=True,
    palette="turbo",
    spacingFactor="0.9",
    start_frame=0,
    end_frame=None,   # <--- THIS IS THE ONLY CHANGE
    viewer="vmd"
)
# Out:
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# /Users/finn/miniconda3/envs/testing_ngl/lib/python3.10/site-packages/MDAnalysis/coordinates/DCD.py:165: DeprecationWarning: DCDReader currently makes independent timesteps by copying self.ts while other readers update self.ts inplace. This behavior will be changed in 3.0 to be the same as other readers. Read more at https://github.com/MDAnalysis/mdanalysis/issues/3889 to learn if this change in behavior might affect you.
#   warnings.warn("DCDReader currently makes independent timesteps"
# Detected B-factor range: 0.34 - 3.41
# [flipbook] Using VMD backend (PTY Mode)...
# [flipbook] Launching VMD in PTY:
#   /Applications/VMD 2.0.0a7-pre2.app/Contents/vmd2/lib/vmd_MACOSXARM64 -dispdev win -e /Users/finn/Documents/GitHub/rmsx/rmsx/vmd_scripts/wait_to_load.tcl -args /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_1_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_2_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_3_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_4_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_5_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_6_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_7_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_8_first_frame.pdb /Users/finn/Documents/GitHub/rmsx/test_files/protease/combined/slice_9_first_frame.pdb turbo

# %%
import glob
from IPython.display import Image, display
imgs = sorted(glob.glob(os.path.join(output_dir_multi, "combined", "*.png")))
if imgs:
    display(Image(filename=imgs[-1]))
else:
    print("No flipbook images found in:", os.path.join(output_dir_multi, "combined"))

# %% [markdown]
# ## 6) Interpreting Results
#
# If you want the flanking plots, `triple=True`, RMSX produces:
# - **RMSX heatmap** (residue × time slice)
# - **RMSD** over time
# - **RMSF** per residue
#
# **Questions to ask:**
# 1. Which residues/regions show the most flexibility?
# 2. When do flexibility spikes occur (early/mid/late)?
# 3. Do multiple intervals of high fluctuation appear?
# 4. How do these align with functional domains or events (e.g., binding, domain motion)?

# %% [markdown]
# ---
# ### Conclusions
#
# You’ve seen how to:
# 1. Install and configure **RMSX** and **Flipbook**
# 2. Run single- and multi-chain analyses
# 3. Generate FlipBook snapshots (optional)
# 4. Interpret RMSX plots (when/where the biggest changes happen)
#
# For more details, visit the GitHub repo or open an issue with questions.
#
# Feel free to email the primary developer Finn Beruldsen at fpberuld@cougarnet.uh.edu if you need anything else.

# %% [markdown]
# ### Acknowledgements
# We thank the following beta tests for their valuable feedback on this tutorial:
# - Mason Kretiv — Texas A&M University
# - Helen Ashdown — NIH Biowulf
# - John Miles — University of Missouri
